# %%
import numpy as np
from PIL import Image

pic = Image.open("t3qWG.png").convert('LA')
#pic.save('greyscale.png')

display(pic)

dataArray = np.asarray(pic, dtype = "uint8")

print(dataArray)

display(Image.fromarray(dataArray))
# Out:
# <PIL.Image.Image image mode=LA size=609x297 at 0x7F8A63FA60D0>
# [[[255 255]
#   [255 255]
#   [255 255]
#   ...
#   [255 255]
#   [255 255]
#   [255 255]]
#
#  [[255 255]
#   [255 255]
#   [255 255]
#   ...
#   [255 255]
#   [255 255]
#   [255 255]]
#
#  [[255 255]
#   [255 255]
#   [255 255]
#   ...
#   [255 255]
#   [255 255]
#   [255 255]]
#
#  ...
#
#  [[255 255]
#   [255 255]
#   [255 255]
#   ...
#   [255 255]
#   [255 255]
#   [255 255]]
#
#  [[255 255]
#   [255 255]
#   [255 255]
#   ...
#   [255 255]
#   [255 255]
#   [255 255]]
#
#  [[255 255]
#   [255 255]
#   [255 255]
#   ...
#   [255 255]
#   [255 255]
#   [255 255]]]
# <PIL.Image.Image image mode=LA size=609x297 at 0x7F8A63A813D0>
